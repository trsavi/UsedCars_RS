# %%
import pandas as pd
import seaborn as sns

cars = pd.read_csv('CarIds.csv')

cars.info()

cars.head()

cars.drop(columns='Unnamed: 0', inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35239 entries, 0 to 35238
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   35239 non-null  int64
#  1   Brend        35239 non-null  object
#  2   Cena         35239 non-null  int64
#  3   Godiste      35239 non-null  int64
#  4   Gorivo       35239 non-null  object
#  5   Karoserija   35239 non-null  object
#  6   Kilometraza  35239 non-null  int64
#  7   Kubikaza     35239 non-null  int64
#  8   Model        35239 non-null  object
#  9   Snaga        35239 non-null  int64
#  10  car_id       35239 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 3.0+ MB

# %%
sns.distplot(cars['Kilometraza'])

# %%
sns.distplot(cars['Kilometraza'])

# %%
import matplotlib.pyplot as plt
data=cars[cars['Brend']=='AUDI']
plt.figure(figsize=(10,5))
sns.boxplot(x='Model',y='Kilometraza', data=data)

# %%
import matplotlib.pyplot as plt
data=cars[cars['Brend']=='AUDI']
plt.figure(figsize=(11,5))
sns.boxplot(x='Model',y='Cena', data=data)

# %%
import matplotlib.pyplot as plt
data=cars[cars['Brend']=='AUDI']
plt.figure(figsize=(10,5))
sns.boxplot(x='Model',y='Snaga', data=data)

# %%
sns.countplot(x='Model', data=cars[cars['Brend']=='AUDI'], order=cars[cars['Brend']=='AUDI']['Model'].value_counts().index)

# %%
ten_price = cars['Cena'].max()*0.7
ten_price
#nine_km = cars['Kilometraza'].max()*0.80
#nine_km
cars[cars['Cena']>=ten_price].count()
# Out:
# Unnamed: 0     784
# Brend          784
# Cena           784
# Godiste        784
# Gorivo         784
# Karoserija     784
# Kilometraza    784
# Kubikaza       784
# Model          784
# Snaga          784
# car_id         784
# dtype: int64

# %%
sns.distplot(cars['Cena'])

# %%
sns.distplot(cars['Godiste'], bins=15)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Model', data=cars[cars['Brend']=='OPEL'])

# %%
data=cars[cars['Brend']=='VOLKSWAGEN']
plt.figure(figsize=(20,5))
sns.boxplot(x='Model',y='Cena', data=data)

# %%
plt.figure(figsize=(18,5))
sns.countplot(x='Model', data=cars[cars['Brend']=='VOLKSWAGEN'], order=cars[cars['Brend']=='VOLKSWAGEN']['Model'].value_counts().index)

# %%
sns.pairplot(cars, hue='Godiste', palette='viridis')

# %%
plt.figure(figsize=(5,10))
sns.scatterplot(x='Godiste', y='Cena', data = cars, hue='Kilometraza')

# %%
plt.figure(figsize=(5,8))
sns.scatterplot('Snaga', 'Kubikaza', data = cars, hue='Gorivo')

# %%
# Here we can see correlation between different type of parameters
plt.figure(figsize=(5,5))
sns.heatmap(cars.corr())
